# %% [markdown]
# <h1 style = 'text-align:center>Tokenization

# %% [markdown]
# # Delimiter based Tokenization(Python’s split function)

# %%
text = 'I love watching cartoons'
text.split()
# Out:
# ['I', 'love', 'watching', 'cartoons']

# %%
text1 = 'I am an Indian. But I like to visit US!'
text1.split('.')
# Out:
# ['I am an Indian', ' But I like to visit US!']

# %% [markdown]
# # Using Regular Expressions

# %%
import re
sentence = '''I can't believe it!
We won the game, and it was such an incredible experience.'''
text = re.compile(r'[.!,]').split(sentence)
text
# Out:
# ["I can't believe it",
#  '\nWe won the game',
#  ' and it was such an incredible experience',
#  '']

# %% [markdown]
# # Using NLTK library

# %%
import nltk
from nltk.tokenize import (word_tokenize,
                          sent_tokenize,
                          TreebankWordTokenizer,
                          wordpunct_tokenize,
                          TweetTokenizer,
                          MWETokenizer)

# %%
text = 'Hope, is the only thing stronger than fear! #Hope'
print(word_tokenize(text))
# Out:
# ['Hope', ',', 'is', 'the', 'only', 'thing', 'stronger', 'than', 'fear', '!', '#', 'Hope']

# %%
text1 = 'I have a Ph.D in A.I'
text2 = "We're here to help mail us at abc@gmail.com"
text3 = 'A 5km ride cost $10.75'

# %%
word_tokenize(text1)
# Out:
# ['I', 'have', 'a', 'Ph.D', 'in', 'A.I']

# %%
word_tokenize(text2)
# Out:
# ['We',
#  "'re",
#  'here',
#  'to',
#  'help',
#  'mail',
#  'us',
#  'at',
#  'abc',
#  '@',
#  'gmail.com']

# %%
word_tokenize(text3)
# Out:
# ['A', '5km', 'ride', 'cost', '$', '10.75']

# %% [markdown]
# ## Punctuation tokenization

# %%
text = 'Hope, is the only thing stronger than fear! #Hope'
print(wordpunct_tokenize(text))
# Out:
# ['Hope', ',', 'is', 'the', 'only', 'thing', 'stronger', 'than', 'fear', '!', '#', 'Hope']

# %% [markdown]
# ## TreeBank Word Tokenizer

# %%
text = "What you don't want to be done to yourself, do'nt do to others 100.0%👍..."
tokenizer = TreebankWordTokenizer()
print(tokenizer.tokenize(text))
# Out:
# ['What', 'you', 'do', "n't", 'want', 'to', 'be', 'done', 'to', 'yourself', ',', "do'nt", 'do', 'to', 'others', '100.0', '%', '👍', '...']

# %% [markdown]
# # Using Spacy
#     -Here we have to convert text to document

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
# Out:
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# ...

# %%
doc1 = nlp(text1)
doc2 = nlp(text2)
doc3 = nlp(text3)

# %%
for token in doc1:
    print(token)
# Out:
# I
# have
# a
# Ph
# .
# D
# in
# A.I

# %%
for token in doc2:
    print(token)
# Out:
# We
# 're
# here
# to
# help
# mail
# us
# at
# abc@gmail.com

# %%
for token in doc3:
    print(token)
# Out:
# A
# 5
# km
# ride
# cost
# $
# 10.75

# %%
word = 'Dr. Strange makes villan to zero with his magic. Hulk makes villan to zero with his power'
doc = nlp(word)

for token in doc.sents:
    print(token)
    
print()
print()

for sentence in doc.sents:
    for word in sentence:
        print(word)
# Out:
# Dr. Strange makes villan to zero with his magic.
# Hulk makes villan to zero with his power
#
#
# Dr.
# Strange
# makes
# villan
# to
# zero
# with
# his
# magic
# .
# Hulk
# makes
# villan
# to
# zero
# with
# his
# power

# %% [markdown]
# # Gensim word Tokenizer

# %%
from gensim.utils import tokenize
list(tokenize(text1))
# Out:
# ['I', 'have', 'a', 'Ph', 'D', 'in', 'A', 'I']
